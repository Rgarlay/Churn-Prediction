# %%
import pandas as pd 
from sqlalchemy import create_engine, MetaData

# %%
engine = create_engine('mysql+pymysql://root:workbench2025@localhost:3306')

# %%
con = engine.connect()

# %%
from sqlalchemy import text

# %%
con.execute(text('create database churn_db'))

# %%
engine = create_engine('mysql+pymysql://root:workbench2025@localhost:3306/churn_db')
con = engine.connect()

# %%
df = pd.read_csv('train.csv')

df.head()
# Out:
#    customer_id  age    location subscription_type payment_plan  \
# 0            1   32     Montana              Free       Yearly
# 1            2   64  New Jersey              Free      Monthly
# 2            3   51  Washington           Premium       Yearly
# 3            4   63  California            Family       Yearly
# 4            5   54  Washington            Family      Monthly
#
#    num_subscription_pauses payment_method customer_service_inquiries  \
# 0                        2         Paypal                     Medium
# 1                        3         Paypal                        Low
# 2                        2    Credit Card                       High
# 3                        4      Apple Pay                     Medium
# 4                        3         Paypal                       High
#
#    signup_date  weekly_hours  average_session_length  song_skip_rate  \
# 0        -1606     22.391362              105.394516        0.176873
# ...

# %%
df.to_sql('churn', con = con,if_exists='replace')
# Out:
# 125000

# %%
df = pd.read_sql("select * from churn limit 10", con=con)
